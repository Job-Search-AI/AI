# %%
# %pip install -q selenium ipywidgets

# %%
import os

cache_dir = '/content/drive/MyDrive/ai_enginner/job_search/AI/cache/'
os.environ['HF_HOME'] = cache_dir

# %%
from src.crawling import crawl_job_html_from_saramin
from src.parsing import parsing_job_info
from config import USER_INFO

# %%
html_contents = crawl_job_html_from_saramin(USER_INFO, 3)
documents = parsing_job_info(html_contents)
# Out:
# 셀레니움 초기화 시작...
# 셀레니움 초기화 완료
# 페이지 로드 시작...
# 접속 URL: https://www.saramin.co.kr/zf_user/search?searchType=search&searchword=AI+%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&loc_mcd=101000&edu_min=6&edu_max=9&edu_none=y&company_cd=0%2C1%2C2%2C3%2C4%2C5%2C6%2C7%2C9%2C10&exp_cd=1&exp_none=y&panel_type=&search_optional_item=y&search_done=y&panel_count=y&preview=y
# 페이지 로드 완료
# 채용 정보 영역 로딩 완료
# 채용 정보 영역 수: 40개
# 추출된 상세 링크 수: 40개
# [1/40] 상세 페이지 접속: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51797639&location=ts&searchword=AI+%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&searchType=search&paid_fl=n&search_uuid=1d7829b0-c601-4567-8b3d-201b17953ac8
# 상세 제목 일치
# 제목 요소 추출 완료
# 요약 요소 추출 완료
# 상세 내용 추출 완료
# 접수기간 및 방법 추출 완료
# 기업정보 추출 완료
# 복리후생 버튼 클릭 실패: Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.jv_cont.jv_benefit button.btn_more_cont"}
#   (Session info: chrome=140.0.7339.82); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# #0 0x58f029b1794a <unknown>
# #1 0x58f02958c8a0 <unknown>
# #2 0x58f0295de540 <unknown>
# #3 0x58f0295de731 <unknown>
# #4 0x58f0295d2216 <unknown>
# #5 0x58f02960405d <unknown>
# #6 0x58f0295d2107 <unknown>
# #7 0x58f0296041fe <unknown>
# #8 0x58f029629c23 <unknown>
# #9 0x58f029603e03 <unknown>
# #10 0x58f0295d0968 <unknown>
# #11 0x58f0295d15e1 <unknown>
# #12 0x58f029adb548 <unknown>
# #13 0x58f029adf272 <unknown>
# #14 0x58f029ac2313 <unknown>
# #15 0x58f029adfdc5 <unknown>
# #16 0x58f029aa749f <unknown>
# #17 0x58f029b04158 <unknown>
# #18 0x58f029b04332 <unknown>
# #19 0x58f029b16a53 <unknown>
# #20 0x7883218d7ac3 <unknown>
#
# 복리후생 내용 추출 실패: Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.jv_cont.jv_benefit"}
#   (Session info: chrome=140.0.7339.82); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# #0 0x58f029b1794a <unknown>
# #1 0x58f02958c8a0 <unknown>
# #2 0x58f0295de540 <unknown>
# #3 0x58f0295de731 <unknown>
# #4 0x58f0295d2216 <unknown>
# #5 0x58f02960405d <unknown>
# #6 0x58f0295d2107 <unknown>
# #7 0x58f0296041fe <unknown>
# #8 0x58f029629c23 <unknown>
# #9 0x58f029603e03 <unknown>
# #10 0x58f0295d0968 <unknown>
# #11 0x58f0295d15e1 <unknown>
# #12 0x58f029adb548 <unknown>
# #13 0x58f029adf272 <unknown>
# #14 0x58f029ac2313 <unknown>
# #15 0x58f029adfdc5 <unknown>
# #16 0x58f029aa749f <unknown>
# #17 0x58f029b04158 <unknown>
# #18 0x58f029b04332 <unknown>
# #19 0x58f029b16a53 <unknown>
# #20 0x7883218d7ac3 <unknown>
#
# 근무지 위치 추출 실패: Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.jv_cont.jv_location"}
#   (Session info: chrome=140.0.7339.82); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# #0 0x58f029b1794a <unknown>
# #1 0x58f02958c8a0 <unknown>
# #2 0x58f0295de540 <unknown>
# #3 0x58f0295de731 <unknown>
# #4 0x58f0295d2216 <unknown>
# #5 0x58f02960405d <unknown>
# #6 0x58f0295d2107 <unknown>
# #7 0x58f0296041fe <unknown>
# #8 0x58f029629c23 <unknown>
# #9 0x58f029603e03 <unknown>
# #10 0x58f0295d0968 <unknown>
# #11 0x58f0295d15e1 <unknown>
# #12 0x58f029adb548 <unknown>
# #13 0x58f029adf272 <unknown>
# #14 0x58f029ac2313 <unknown>
# #15 0x58f029adfdc5 <unknown>
# #16 0x58f029aa749f <unknown>
# #17 0x58f029b04158 <unknown>
# #18 0x58f029b04332 <unknown>
# #19 0x58f029b16a53 <unknown>
# #20 0x7883218d7ac3 <unknown>
#
# 지원자 통계 추출 완료
# 공고 1 수집 완료
# [2/40] 상세 페이지 접속: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51808455&location=ts&searchword=AI+%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&searchType=search&paid_fl=n&search_uuid=1d7829b0-c601-4567-8b3d-201b17953ac8
# 상세 제목 일치
# 제목 요소 추출 완료
# 요약 요소 추출 완료
# 상세 내용 추출 완료
# 접수기간 및 방법 추출 완료
# 기업정보 추출 완료
# 복리후생 버튼 클릭 실패: Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.jv_cont.jv_benefit button.btn_more_cont"}
#   (Session info: chrome=140.0.7339.82); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# #0 0x58f029b1794a <unknown>
# #1 0x58f02958c8a0 <unknown>
# #2 0x58f0295de540 <unknown>
# #3 0x58f0295de731 <unknown>
# #4 0x58f0295d2216 <unknown>
# #5 0x58f02960405d <unknown>
# #6 0x58f0295d2107 <unknown>
# #7 0x58f0296041fe <unknown>
# #8 0x58f029629c23 <unknown>
# #9 0x58f029603e03 <unknown>
# #10 0x58f0295d0968 <unknown>
# #11 0x58f0295d15e1 <unknown>
# #12 0x58f029adb548 <unknown>
# #13 0x58f029adf272 <unknown>
# #14 0x58f029ac2313 <unknown>
# #15 0x58f029adfdc5 <unknown>
# #16 0x58f029aa749f <unknown>
# #17 0x58f029b04158 <unknown>
# #18 0x58f029b04332 <unknown>
# #19 0x58f029b16a53 <unknown>
# #20 0x7883218d7ac3 <unknown>
#
# 복리후생 내용 추출 실패: Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.jv_cont.jv_benefit"}
#   (Session info: chrome=140.0.7339.82); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# #0 0x58f029b1794a <unknown>
# #1 0x58f02958c8a0 <unknown>
# #2 0x58f0295de540 <unknown>
# #3 0x58f0295de731 <unknown>
# #4 0x58f0295d2216 <unknown>
# #5 0x58f02960405d <unknown>
# #6 0x58f0295d2107 <unknown>
# #7 0x58f0296041fe <unknown>
# #8 0x58f029629c23 <unknown>
# #9 0x58f029603e03 <unknown>
# #10 0x58f0295d0968 <unknown>
# #11 0x58f0295d15e1 <unknown>
# #12 0x58f029adb548 <unknown>
# #13 0x58f029adf272 <unknown>
# #14 0x58f029ac2313 <unknown>
# #15 0x58f029adfdc5 <unknown>
# #16 0x58f029aa749f <unknown>
# #17 0x58f029b04158 <unknown>
# #18 0x58f029b04332 <unknown>
# #19 0x58f029b16a53 <unknown>
# #20 0x7883218d7ac3 <unknown>
#
# 근무지 위치 추출 실패: Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.jv_cont.jv_location"}
#   (Session info: chrome=140.0.7339.82); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# #0 0x58f029b1794a <unknown>
# #1 0x58f02958c8a0 <unknown>
# #2 0x58f0295de540 <unknown>
# #3 0x58f0295de731 <unknown>
# #4 0x58f0295d2216 <unknown>
# #5 0x58f02960405d <unknown>
# #6 0x58f0295d2107 <unknown>
# #7 0x58f0296041fe <unknown>
# #8 0x58f029629c23 <unknown>
# #9 0x58f029603e03 <unknown>
# #10 0x58f0295d0968 <unknown>
# #11 0x58f0295d15e1 <unknown>
# #12 0x58f029adb548 <unknown>
# #13 0x58f029adf272 <unknown>
# #14 0x58f029ac2313 <unknown>
# #15 0x58f029adfdc5 <unknown>
# #16 0x58f029aa749f <unknown>
# #17 0x58f029b04158 <unknown>
# #18 0x58f029b04332 <unknown>
# #19 0x58f029b16a53 <unknown>
# #20 0x7883218d7ac3 <unknown>
#
# 지원자 통계 추출 실패: Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.jv_cont.jv_statics"}
#   (Session info: chrome=140.0.7339.82); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# #0 0x58f029b1794a <unknown>
# #1 0x58f02958c8a0 <unknown>
# #2 0x58f0295de540 <unknown>
# #3 0x58f0295de731 <unknown>
# #4 0x58f0295d2216 <unknown>
# #5 0x58f02960405d <unknown>
# #6 0x58f0295d2107 <unknown>
# #7 0x58f0296041fe <unknown>
# #8 0x58f029629c23 <unknown>
# #9 0x58f029603e03 <unknown>
# #10 0x58f0295d0968 <unknown>
# #11 0x58f0295d15e1 <unknown>
# #12 0x58f029adb548 <unknown>
# #13 0x58f029adf272 <unknown>
# #14 0x58f029ac2313 <unknown>
# #15 0x58f029adfdc5 <unknown>
# #16 0x58f029aa749f <unknown>
# #17 0x58f029b04158 <unknown>
# #18 0x58f029b04332 <unknown>
# #19 0x58f029b16a53 <unknown>
# #20 0x7883218d7ac3 <unknown>
#
# 공고 2 수집 완료
# [3/40] 상세 페이지 접속: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51739840&location=ts&searchword=AI+%EC%97%94%EC%A7%80%EB%8B%88%EC%96%B4&searchType=search&paid_fl=n&search_uuid=1d7829b0-c601-4567-8b3d-201b17953ac8
# 상세 제목 일치
# 제목 요소 추출 완료
# 요약 요소 추출 완료
# 상세 내용 추출 완료
# 접수기간 및 방법 추출 완료
# 기업정보 추출 실패: Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.jv_cont.jv_company"}
#   (Session info: chrome=140.0.7339.82); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# #0 0x58f029b1794a <unknown>
# #1 0x58f02958c8a0 <unknown>
# #2 0x58f0295de540 <unknown>
# #3 0x58f0295de731 <unknown>
# #4 0x58f0295d2216 <unknown>
# #5 0x58f02960405d <unknown>
# #6 0x58f0295d2107 <unknown>
# #7 0x58f0296041fe <unknown>
# #8 0x58f029629c23 <unknown>
# #9 0x58f029603e03 <unknown>
# #10 0x58f0295d0968 <unknown>
# #11 0x58f0295d15e1 <unknown>
# #12 0x58f029adb548 <unknown>
# #13 0x58f029adf272 <unknown>
# #14 0x58f029ac2313 <unknown>
# #15 0x58f029adfdc5 <unknown>
# #16 0x58f029aa749f <unknown>
# #17 0x58f029b04158 <unknown>
# #18 0x58f029b04332 <unknown>
# #19 0x58f029b16a53 <unknown>
# #20 0x7883218d7ac3 <unknown>
#
# 복리후생 버튼 클릭 실패: Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.jv_cont.jv_benefit button.btn_more_cont"}
#   (Session info: chrome=140.0.7339.82); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# #0 0x58f029b1794a <unknown>
# #1 0x58f02958c8a0 <unknown>
# #2 0x58f0295de540 <unknown>
# #3 0x58f0295de731 <unknown>
# #4 0x58f0295d2216 <unknown>
# #5 0x58f02960405d <unknown>
# #6 0x58f0295d2107 <unknown>
# #7 0x58f0296041fe <unknown>
# #8 0x58f029629c23 <unknown>
# #9 0x58f029603e03 <unknown>
# #10 0x58f0295d0968 <unknown>
# #11 0x58f0295d15e1 <unknown>
# #12 0x58f029adb548 <unknown>
# #13 0x58f029adf272 <unknown>
# #14 0x58f029ac2313 <unknown>
# #15 0x58f029adfdc5 <unknown>
# #16 0x58f029aa749f <unknown>
# #17 0x58f029b04158 <unknown>
# #18 0x58f029b04332 <unknown>
# #19 0x58f029b16a53 <unknown>
# #20 0x7883218d7ac3 <unknown>
#
# 복리후생 내용 추출 완료
# 근무지 위치 추출 실패: Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.jv_cont.jv_location"}
#   (Session info: chrome=140.0.7339.82); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# #0 0x58f029b1794a <unknown>
# #1 0x58f02958c8a0 <unknown>
# #2 0x58f0295de540 <unknown>
# #3 0x58f0295de731 <unknown>
# #4 0x58f0295d2216 <unknown>
# #5 0x58f02960405d <unknown>
# #6 0x58f0295d2107 <unknown>
# #7 0x58f0296041fe <unknown>
# #8 0x58f029629c23 <unknown>
# #9 0x58f029603e03 <unknown>
# #10 0x58f0295d0968 <unknown>
# #11 0x58f0295d15e1 <unknown>
# #12 0x58f029adb548 <unknown>
# #13 0x58f029adf272 <unknown>
# #14 0x58f029ac2313 <unknown>
# #15 0x58f029adfdc5 <unknown>
# #16 0x58f029aa749f <unknown>
# #17 0x58f029b04158 <unknown>
# #18 0x58f029b04332 <unknown>
# #19 0x58f029b16a53 <unknown>
# #20 0x7883218d7ac3 <unknown>
#
# 지원자 통계 추출 실패: Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.jv_cont.jv_statics"}
#   (Session info: chrome=140.0.7339.82); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# #0 0x58f029b1794a <unknown>
# #1 0x58f02958c8a0 <unknown>
# #2 0x58f0295de540 <unknown>
# #3 0x58f0295de731 <unknown>
# #4 0x58f0295d2216 <unknown>
# #5 0x58f02960405d <unknown>
# #6 0x58f0295d2107 <unknown>
# #7 0x58f0296041fe <unknown>
# #8 0x58f029629c23 <unknown>
# #9 0x58f029603e03 <unknown>
# #10 0x58f0295d0968 <unknown>
# #11 0x58f0295d15e1 <unknown>
# #12 0x58f029adb548 <unknown>
# #13 0x58f029adf272 <unknown>
# #14 0x58f029ac2313 <unknown>
# #15 0x58f029adfdc5 <unknown>
# #16 0x58f029aa749f <unknown>
# #17 0x58f029b04158 <unknown>
# #18 0x58f029b04332 <unknown>
# #19 0x58f029b16a53 <unknown>
# #20 0x7883218d7ac3 <unknown>
#
# 공고 3 수집 완료

# %%
from src.embedding import similarity_docs_retrieval

# %%
query = "신입, 학력무관, 고졸이상 공고중에서 AI 엔지니어 공고들만 보여줘."

retrieved_documents, retrieved_scores = similarity_docs_retrieval(query, documents)
# Out:
# ---------- 유사도 검색 시작 ----------
# === Device 정보 ===
# 선택된 device: cpu
# CPU 사용
# PyTorch 버전: 2.8.0+cu126
# ====================
# 모델 로드 시작
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# 모델 로드 완료
# documents를 문자열로 변환 시작
# documents를 문자열로 변환 완료
# 임베딩 계산 시작
# 임베딩 계산 완료
# 코사인 유사도 점수 계산 시작
# 코사인 유사도 점수 계산 완료
# 문서와 유사도 점수 쌍 생성 및 정렬 시작
# 문서와 유사도 점수 쌍 생성 및 정렬 완료
# 문서와 유사도 점수 쌍 출력 시작
# 0.6215: **********
#
# ----------
# 공고제목:
# AI Engineering 인턴
# ----------
#
# ----------
# 요약 정보:
# 경력: 신입
# 학력: 학력무관
# 근무형태: ...
# 0.5171: **********
#
# ----------
# 공고제목:
# AI Software Engineer (신입)
# ----------
#
# ----------
# 요약 정보:
# 경력: 신입
# 학력: 고교졸...
# 0.3916: **********
#
# ----------
# 공고제목:
# 대기업 주도의 생성형AI 활용 사이버보안 전문인력 모집
# ----------
#
# ----------
# 요약 정보:
# 경력: 신입
# 학력...
# 문서와 유사도 점수 쌍 출력 완료

# %%
for i, doc in enumerate(retrieved_documents):
    print(doc)
    print(retrieved_scores[i])
# Out:
# **********
#
# ----------
# 공고제목:
# AI Engineering 인턴
# ----------
#
# ----------
# 요약 정보:
# 경력: 신입
# 학력: 학력무관
# 근무형태: 인턴직3개월
# 우대사항: 우대사항상세보기활동/경험해당직무 근무경험자격/능력AI SaaS, 자동화 도구 또는 AI SDK 사용 경험자닫기 - 우대사항 상세
#
# 급여: 면접 후 결정
# 출퇴근 시간: 09:00~18:00
# 근무지역: 서울 서초구
#
# ----------
#
# ----------
# 복리후생:
# 교육/생활: 식비 지원
# ----------
#
#
#
# ----------
# 상세내용:
# 채용공고
#
# 함께 일할 동료를 찾고 있어요⚡
# : 데이터-사내 고객 업무 자동화 지원, 새로운 툴/플랫폼 학습 및 적용 등
# 이런 분과 함께 하고 싶어요✋
# : 학력무관 / 신입, 새로운 소프트웨어/자동화 툴을 독립적으로 학습하고 적용한 경험 있는 분이라면 좋겠어요
# 근무 지역은 여기에요⭐
# : 서울 서초구
# 함께 일할 동료를 찾습니다✅
# : 0명
# 이렇게 지원해주세요⌛
# : 2025-09-15(월) 23:59까지, 채용 시 마감 예정이에요✨
# ※ 상세 모집요강 및 접수방법은[홈페이지 지원] 참조 바랍니다⭐
#
# ⭐ 치열한 경쟁에서 인사담당자 눈에 띄는 전략 ✅이력서 하이라이트 하러가기✅
# ----------
#
# ----------
# 지원 방법 정보:
# 남은 기간: 남은 기간3일13:02:28
#
# 시작일: 2025.09.04 00:00
# 마감일: 2025.09.15 23:59
#
# 지원방법: 홈페이지 지원 (URL: #)
# 접수양식: 제출서류 보기제출서류이력서, 자기소개서닫기
#
# ----------
#
#
#
#
#
# **********
# tensor(0.6215)
# **********
#
# ----------
# 공고제목:
# AI Software Engineer (신입)
# ----------
#
# ----------
# 요약 정보:
# 경력: 신입
# 학력: 고교졸업 이상
# 근무형태: 정규직
#
# 급여: 회사내규에 따름
# 근무지역: 서울 강남구, 서울전체, 서초구
#
# ----------
#
#
#
#
#
# ----------
# 상세내용:
# AI Software Engineer (신입)
# 서비스 소개
# http://www.agilesoda.com/
# 이 포지션의 AI 예상 면접 질문이 궁금하다면 점핏에서 확인해보세요!
# 모집부문 / 상세내용
# 사용 기술
# Python React MongoDB MariaDB FastAPI Docker Kubernetes Node.js TypeScript
# 주요업무
# • RAG 시스템 인프라 설계 및 구축
# • 데이터 파이프라인 구축
# • LLM 기반 AI 시스템 또는 Agent Workflow 시스템 개발
# • MLOps,LLMOps 환경 구축 및 운영
# • AI-OCR 시스템 구축 및 운영
# 자격요건
# • Python 기반 AI 서비스 개발 경험이 있는 분
# • FastAPI 등 Python 웹프레임워크 개발 경험이 있는 분
# • React 기반 Frontend 개발 경험이 있는 분
# • Docker, Kubernetes 환경 서비스 개발 경험이 있는 분
# • RAG 시스템 구축 및 운영 경험이 있는 분
# • MariaDB, PostgreSQL 등 다양한 형태의 데이터베이스 경험이 있는 분
# • x-javascript/TypeScript, Node.js 기반 backend 개발 경험이 있는 분
# 우대사항
# • AI MLOps,LLMOps에 대한 이해가 있으신 분
# • AWS,GCP,Azure 등 클라우드 기반의 AI인프라 구축 및 관리 경험
# • LangChain, LlamaIndex 등 LLM 프레임워크 경험
# • 벡터 DB 및 검색 엔진 활용 경험
# • LLM 성능 최적화를 위한 프롬프트 엔지니어링 또는 RAG 구조 최적화 경험
# • AI 도구를 통한 개발자 생산성 향상, 자동화 개발 유경험자
# • GitHub 기여, 기술 블로그 운영, 개발 커뮤니티 참여 경험
# • 기술만이 아닌 ‘사용자 가치’를 고민하는 제품 중심 사고
# 마감일 및 근무지
# • 마감일 : 2025년 10월 09일
# • 근무지
# - 서울 강남구 선릉로 525, 3층
# 복지 및 혜택
# • 시차출퇴근제 운영
# 오전 7시~10시 사이 유연한 출퇴근으로 자율성과 몰입을 지원합니다.
#
# • 닉네임제 운영
# 닉네임 제도 운영을 통해 수평적 커뮤니케이션을 지향합니다.
#
# • 스톡옵션 제도 운영
# 회사의 성과를 함께 나눌 수 있도록 스톡옵션을 제공합니다.
#
# • 성과에 따른 인센티브 지급
# 수고와 노력이 정당하게 보상받을 수 있도록 인센티브를 지급합니다.
#
# • 음료 무제한 제공
# 다양한 음료를 자유롭게 즐길 수 있도록 다양한 음료를 무제한 제공합니다.
#
# • 점심 식대 실비 지원
# 연봉에 포함되지 않는 월 20만원 가량의 식대를 제공해 점심시간의 부담을 덜어드립니다.
#
# • 야근 및 휴일 근무 식대, 교통비 지원
# 연봉에 포함되지 않는 야근 및 휴일 근무 식대와 교통비를 제공합니다.
#
# • 건강 검진 지원
# 건강하게 함께 일할 수 있도록 30만원 상당의 종합 검진을 제공합니다.
#
# • 명절 선물 지급
# 따뜻한 명절을 보낼 수 있도록 명절 선물을 제공합니다.
#
# • 생일 상품권 지급
# 특별한 하루를 함께 축하하기 위해 생일 상품권을 지급합니다.
#
# • 장기 근속 포상제도 운영
# 오랜 시간 함께한 장기 근속 직원에게 포상금을 지급합니다.
#
# • 경조휴가 및 경조금 지원
# 기쁨과 슬픔을 함께 나누도록 경조사 시 휴가와 경조금을 지원합니다.
#
# • 직무 발명 포상제도 운영
# 업무 관련 특허를 보상하여 직원의 창의적인 노력을 인정합니다.
#
# • 인재 추천 포상금 지급
# 인재 추천 시 포상금 100만원을 지급합니다.
#
# • 도서 구매 지원
# 업무에 필요한 도서 구입을 지원합니다.
#
# • 교육 지원
# 직무 역량 향상을 위한 교육 비용을 지원합니다.
#
# • 사내 동호회 활동 지원
# 다양한 사내 동호회 활동을 지원합니다.
# 채용절차 및 기타 지원 유의사항
# 서류전형 - 1차 면접(본부장, 팀장) - 2차 면접(대표이사) - 처우협의&입사일 조정
# ----------
#
# ----------
# 지원 방법 정보:
# 남은 기간: 남은 기간27일13:02:56
#
# 시작일: 2025.09.10 00:00
# 마감일: 2025.10.09 23:59
#
# 지원방법: 사람인 입사지원,점핏에서 지원 (URL: https://jumpit.saramin.co.kr/position/51797639?utm_source=saramin&utm_medium=position&utm_campaign=apply&utm_term=homepage_btn)
# 접수양식: 제출서류 보기제출서류이력서, 자기소개서닫기
#
# ----------
#
# ----------
# 지원자 통계:
# 지원자수: 13
#
# 성별 현황:
#   남자: 비율 78, 인원 7 명
#   여자: 비율 22, 인원 2 명
#
# 연령별 현황:
#   20대: 11
#   30대: 2
#   40대: 0
#   50대: 0
#   60대 이상: 0
#
# 학력별 현황:
#   고졸이하: 3
#   2~3년제: 0
#   4년제: 8
#   석사: 2
#   박사: 0
#
# 경력별 현황:
#   신입: 4
#   1년 미만: 3
#   1~3년: 2
#   3~5년: 3
#   5년 이상: 1
#
# 연봉별 현황:
#   2,200~2,600: 0
#   2,600~3,000: 0
#   3,000~4,000: 2
#   4,000이상: 0
#
# 외국어 현황:
#   TOEIC: 0
#   TOEFL: 0
#   TEPS: 0
#   TOEIC Speaking: 0
#   OPIC: 1
#   JPT: 0
#   HSK: 0
#   기타: 3
#
# OPIC:
#   IL이하: 0
#   IM1: 1
#   IM2: 0
#   IM3: 0
#   IH: 0
#   AL: 0
#
# 자격증 현황:
#   컴퓨터활용능력..: 1
#   정보처리기사: 1
#   1종대형운전면허: 1
#   1종보통운전면허: 1
#   IELTS: 1
#   기타: 3
#
# 자격증 개수:
#   미보유: 8
#   1개: 4
#   2개: 0
#   3개: 0
#   4개이상: 1
#
# 포트폴리오 및 기타문서 제출:
#   포트폴리오: 비율 9, 인원 N/A
#
# ----------
#
# ----------
# 회사 정보:
# 회사명: (주)애자일소다관심기업
# 대표자명: 최대우
# 기업형태: 중소기업
# 업종: 응용 소프트웨어 개발 및 공급업
# 사원수: 77 명(2025년 기준)
# 설립일: 2015년 4월 17일(업력 11년차)
# 매출액: 60억 9,778만원(2024년 기준)
# 홈페이지: agilesoda.com
# 기업주소: 서울 강남구 선릉로 525, 3층 (역삼동,인포스톰빌딩)
# ----------
#
# **********
# tensor(0.5171)
# **********
#
# ----------
# 공고제목:
# 대기업 주도의 생성형AI 활용 사이버보안 전문인력 모집
# ----------
#
# ----------
# 요약 정보:
# 경력: 신입
# 학력: 학력무관(예정자 가능)
# 근무형태: 교육생
#
# 급여: 면접 후 결정
# 근무요일: 주 5일(월~금)
# 근무지역: 서울전체, 서울 강남구, 마포구, 서초구, 송파구, 종로구, 경기전체, 경기 광주시, 성남시, 용인시
#
# ----------
#
#
#
#
#
# ----------
# 상세내용:
#
# ----------
#
# ----------
# 지원 방법 정보:
# 남은 기간: 남은 기간32일13:02:38
#
# 시작일: 2025.09.11 00:00
# 마감일: 2025.10.14 23:59
#
# 지원방법: 홈페이지 지원 (URL: #)
# 접수양식: 제출서류 보기제출서류이력서, 자기소개서닫기
#
# ----------
#
#
#
# ----------
# 회사 정보:
# 회사명: 에스케이쉴더스(주)관심기업
# 대표자명: 민기식
# 기업형태: 대기업, 1000대기업, 주식회사
# 업종: 보안시스템 서비스업
# 사원수: 6,918 명(2023년 기준)
# 설립일: 2000년 6월 26일(업력 26년차)
# 홈페이지: https://skshieldus.com/
# 기업주소: 경기 성남시 분당구 판교로227번길 23
# ----------
#
# **********
# tensor(0.3916)

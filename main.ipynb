# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install -q selenium
# %pip install -q ipywidgets
# %pip install -q -U bitsandbytes
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 95.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.2/499.2 kB 46.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 29.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 36.5 MB/s eta 0:00:00

# %%
import sys
import os

# %%
cache_dir = '/content/drive/MyDrive/ai_enginner/job_search/AI/cache/'
project_dir = '/content/drive/MyDrive/ai_enginner/job_search/AI/'
sys.path.append(project_dir)
os.environ['HF_HOME'] = cache_dir
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python312.zip',
#  '/usr/lib/python3.12',
#  '/usr/lib/python3.12/lib-dynload',
#  '',
#  '/usr/local/lib/python3.12/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.12/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/drive/MyDrive/ai_enginner/job_search/AI/']

# %%
# 각 모듈에서 필요한 함수들을 직접 import
from src.crawling.html_info_extractor import extract_job_major_info, print_job_summary
from src.crawling.job_crawler import crawl_job_html_from_saramin
from src.embedding.model import similarity_docs_retrieval
from src.llm.generator import generate_response

print("모든 함수들이 성공적으로 import되었습니다!")
# Out:
# 모든 함수들이 성공적으로 import되었습니다!

# %%
# 더미 데이터 생성
user_info = {
        "cat_kewd": "84", # 직무 코드
        "keydownAccess": "", # 검색 키워드
        "loc_mcd": "101000", # 지역 코드
        "exp_cd": "1", # 경력 코드
        "exp_none": "y", # 경력 무관
        "edu_none": "y", # 학력 무관
        "edu_min": "6", # 학력 최소
        "edu_max": "9", # 학력 최대
        "search_done": "y", # 검색 완료
    }

# 사람인 채용 정보 html 추출
html_content = crawl_job_html_from_saramin(user_info)

# #content > div.recruit_list_renew > div 영역 내의 채용 정보 추출
job_data = extract_job_major_info(html_content)

# 채용 정보 요약 출력
print_job_summary(job_data)
# Out:
# 셀레니움 초기화 시작...
# 셀레니움 초기화 완료
# 페이지 로드 시작...
# 접속 URL: https://www.saramin.co.kr/zf_user/search?cat_kewd=84&keydownAccess=&loc_mcd=101000&exp_cd=1&exp_none=y&edu_none=y&edu_min=6&edu_max=9&search_done=y
# 페이지 로드 완료
# 채용 정보 영역 로딩 완료
# 채용 정보 영역 수: 40개
# 추출된 영역 HTML 길이: 220101 문자
# 추출된 채용 항목 수: 40개
#
# === 채용 정보 요약 ===
# 총 40개의 채용 공고를 찾았습니다.
#
# [1]
#     제목: [시드소프트]SI개발&웹개발&백엔드/서버개발 외 정규직 채용
#     직무: 백엔드/서버개발,웹개발,SI개발,소프트웨어개발수정일 25/08/31
#     근무지: 서울구로구
#     경력: 신입
#     학력: 학력무관
#     마감일: ~ 09/08(월)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51266037&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [2]
#     제목: 영어회화 가능자
#     직무: 백엔드/서버개발,기술지원,데이터엔지니어,IT컨설팅,SE(시스템엔지니어)외수정일 25/08/29
#     근무지: 서울양천구
#     경력: 신입
#     학력: 학력무관
#     마감일: 내일마감
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51688737&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [3]
#     제목: 2025년도 신입직원 채용공고
#     직무: 백엔드/서버개발,프론트엔드,데이터분석가,데이터엔지니어,정보보안외수정일 25/09/03
#     근무지: 서울전체
#     경력: 신입
#     학력: 학력무관
#     마감일: ~ 09/12(금)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51720555&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [4]
#     제목: 백엔드개발자(Node.js) [신입]
#     직무: 백엔드/서버개발,MySQL,ElasticStack,Node.js,PostgreSQL외수정일 25/09/03
#     근무지: 서울전체
#     경력: 신입
#     학력: 학력무관
#     마감일: ~ 10/02(목)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51722568&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [5]
#     제목: 백엔드개발 산업기능요원
#     직무: 백엔드/서버개발,MySQL,ElasticStack,Node.js,PostgreSQL외수정일 25/09/03
#     근무지: 서울전체
#     경력: 신입
#     학력: 학력무관
#     마감일: ~ 10/02(목)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51722528&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [6]
#     제목: [신입] 플렉스지 유지보수 개발 및 운영 모집
#     직무: 백엔드/서버개발,웹개발,Java,.NET,Ajax외수정일 25/09/03
#     근무지: 서울금천구
#     경력: 신입
#     학력: 학력무관
#     마감일: 채용시
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51383887&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [7]
#     제목: [신입] JAVA 웹 개발자 채용
#     직무: 백엔드/서버개발,웹개발,프론트엔드,유지보수,정보보안외수정일 25/08/29
#     근무지: 서울금천구
#     경력: 신입
#     학력: 학력무관
#     마감일: ~ 09/30(화)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51690978&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [8]
#     제목: IT B2B 기술영업 및 세일즈
#     직무: 백엔드/서버개발,웹개발,앱개발,QA/테스터,RTOS외수정일 25/08/27
#     근무지: 서울영등포구
#     경력: 신입
#     학력: 고졸↑
#     마감일: ~ 09/25(목)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51487131&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [9]
#     제목: [신입] 모바일 RTS 클라이언트 & 서버/MMORPG 클라이언트
#     직무: 백엔드/서버개발,웹개발,Java,앱개발,Javascript외수정일 25/08/28
#     근무지: 서울서초구
#     경력: 신입
#     학력: 학력무관
#     마감일: ~ 10/25(토)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51656784&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [10]
#     제목: 백업 / 보안 / 스토리지/ snfs 서버 정규직 채용합니다
#     직무: 백엔드/서버개발,프론트엔드,유지보수,정보보안,SE(시스템엔지니어)외등록일 25/08/28
#     근무지: 서울송파구
#     경력: 신입
#     학력: 학력무관
#     마감일: ~ 09/27(토)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51675516&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [11]
#     제목: [캐시워크] 데이터엔지니어 인턴
#     직무: 백엔드/서버개발,웹개발,Java,앱개발,Python외등록일 25/08/13
#     근무지: 서울강남구
#     경력: 신입
#     학력: 학력무관
#     마감일: ~ 10/12(일)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51551591&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [12]
#     제목: [신입] Backend(Java) 개발자 채용 공고
#     직무: 백엔드/서버개발,웹개발,프론트엔드,Java,Javascript외등록일 25/08/14
#     근무지: 서울구로구
#     경력: 신입
#     학력: 학력무관
#     마감일: ~ 09/13(토)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51562570&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [13]
#     제목: [캐시워크] 백엔드개발 채용전환형 인턴
#     직무: 백엔드/서버개발,웹개발,Java,앱개발,Python외등록일 25/08/06
#     근무지: 서울강남구
#     경력: 신입
#     학력: 학력무관
#     마감일: ~ 10/05(일)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51490875&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [14]
#     제목: Ai Agent Developer 채용
#     직무: 백엔드/서버개발,Javascript,Python,데이터분석가,데이터엔지니어외등록일 25/08/04
#     근무지: 서울강남구
#     경력: 신입
#     학력: 학력무관
#     마감일: ~ 09/06(토)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51460431&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [15]
#     제목: [국비교육생 모집]자바·빅데이터 취업훈련
#     직무: 백엔드/서버개발,프론트엔드,Java,Javascript,Python외수정일 25/09/04
#     근무지: 서울전체
#     경력: 경력무관
#     학력: 학력무관
#     마감일: ~ 09/16(화)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51741651&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [16]
#     제목: [81%취업] 빅데이터,AI 무료취업과정 모집!
#     직무: 백엔드/서버개발,웹개발,Java,앱개발,Python외수정일 25/08/12
#     근무지: 광주남구
#     경력: 경력무관
#     학력: 학력무관
#     마감일: ~ 04/08(수)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51127978&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [17]
#     제목: 백엔드/서버개발자 모집
#     직무: 백엔드/서버개발,안드로이드,텔레매틱스,모바일APP,무선통신등록일 25/09/03
#     근무지: 서울구로구
#     경력: 경력무관
#     학력: 학력무관
#     마감일: ~ 11/02(일)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51727994&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [18]
#     제목: ㈜위즈코리아 '25년 하반기 신입/경력 사원 모집
#     직무: 백엔드/서버개발,웹개발,프론트엔드,Java,Javascript외수정일 25/08/29
#     근무지: 서울전체
#     경력: 신입·경력
#     학력: 학력무관
#     마감일: ~ 09/30(화)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51160084&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [19]
#     제목: ㈜위즈코리아 SE(시스템 엔지니어), PM 채용
#     직무: 백엔드/서버개발,웹개발,유지보수,정보보안,솔루션외수정일 25/08/29
#     근무지: 서울전체
#     경력: 신입·경력
#     학력: 학력무관
#     마감일: ~ 09/30(화)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51160613&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [20]
#     제목: PM 거래처영업/관리  아웃소싱관리 S/W 개발자 채용
#     직무: 백엔드/서버개발,웹개발,Python,SI개발,임베디드외수정일 25/08/19
#     근무지: 서울강서구
#     경력: 신입·경력
#     학력: 학력무관
#     마감일: ~ 09/17(수)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51590963&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [21]
#     제목: 2025년 하반기 신입 및 경력 대규모 채용
#     직무: 백엔드/서버개발,프론트엔드,사무보조,경영지원,광고영업외수정일 25/09/01
#     근무지: 서울전체
#     경력: 신입·경력
#     학력: 학력무관
#     마감일: ~ 09/30(화)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51161938&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [22]
#     제목: [게임/IT] 취업 연계 연수생 모집
#     직무: 백엔드/서버개발,웹개발,Java,앱개발,유지보수외수정일 25/08/08
#     근무지: 서울전체
#     경력: 경력무관
#     학력: 학력무관
#     마감일: 오늘마감
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51502151&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [23]
#     제목: [광고대행사] 개발팀 채용공고
#     직무: 백엔드/서버개발,프론트엔드,유지보수,API,DevOps외수정일 25/07/28
#     근무지: 서울금천구
#     경력: 경력무관
#     학력: 학력무관
#     마감일: 채용시
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51391424&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [24]
#     제목: 신입 및 경력직원 채용공고
#     직무: 백엔드/서버개발,유지보수,MySQL,기술지원,웹마스터외수정일 25/08/29
#     근무지: 서울전체
#     경력: 신입·경력
#     학력: 학력무관
#     마감일: ~ 09/10(수)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51146371&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [25]
#     제목: ㈜우진플라임 부문별 인재채용
#     직무: 백엔드/서버개발,웹개발,앱개발,유지보수,SI개발외수정일 25/09/01
#     근무지: 서울전체
#     경력: 신입·경력
#     학력: 학력무관
#     마감일: ~ 09/30(화)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51693469&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [26]
#     제목: (주)세피스 그룹웨어 솔루션 개발(C#,Net MVC) 신입/경력 채용
#     직무: 백엔드/서버개발,웹개발,프론트엔드,.NET,C#외등록일 25/09/04
#     근무지: 서울금천구
#     경력: 신입·경력
#     학력: 학력무관
#     마감일: ~ 10/04(토)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51747086&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [27]
#     제목: [국비무료IT취업]자바파이썬/웹개발/빅데이터/인공지능
#     직무: 백엔드/서버개발,웹개발,프론트엔드,Java,앱개발외수정일 25/09/04
#     근무지: 서울마포구
#     경력: 경력무관
#     학력: 학력무관
#     마감일: ~ 09/07(일)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51502181&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [28]
#     제목: [서비시개발] 서비스 기획 및 백엔드, 프론트엔드 개발 채용
#     직무: 백엔드/서버개발,앱개발,서비스기획,SI·시스템통합,소프트웨어개발등록일 25/09/04
#     근무지: 서울성동구
#     경력: 경력무관
#     학력: 학력무관
#     마감일: ~ 10/04(토)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51746872&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [29]
#     제목: 파이썬(Python) 기반의 풀스택 개발자 모십니다.
#     직무: 백엔드/서버개발,프론트엔드,Javascript,Python,유지보수외등록일 25/09/04
#     근무지: 서울강남구
#     경력: 경력무관
#     학력: 고졸↑
#     마감일: ~ 09/07(일)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51746270&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [30]
#     제목: KT Cloud 테크센터 인력 모집 (스케줄 근무)
#     직무: 백엔드/서버개발,SE(시스템엔지니어),Windows,Linux,시스템관리등록일 25/09/04
#     근무지: 서울양천구
#     경력: 경력무관
#     학력: 고졸↑
#     마감일: ~ 10/04(토)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51743051&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [31]
#     제목: (주)미스릴 인공지능 연구개발 담당 연구원 모집
#     직무: 백엔드/서버개발,웹개발,프론트엔드,Python,IT컨설팅외수정일 25/09/04
#     근무지: 서울송파구
#     경력: 신입·경력
#     학력: 학력무관
#     마감일: ~ 10/02(목)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51722722&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [32]
#     제목: AI 지능형 CCTV, 우수조달 제품 영업담당
#     직무: 백엔드/서버개발,기술영업,솔루션기술영업,IT영업,SI영업외수정일 25/09/04
#     근무지: 서울송파구
#     경력: 신입·경력
#     학력: 학력무관
#     마감일: 상시채용
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51239407&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [33]
#     제목: Product Engineer 인턴 (채용 연계형)
#     직무: 백엔드/서버개발,웹개발,프론트엔드,앱개발,기술지원수정일 25/09/04
#     근무지: 서울서초구
#     경력: 경력무관
#     학력: 학력무관
#     마감일: ~ 09/15(월)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51739723&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [34]
#     제목: 2025년 해커스 교육그룹 [신입/경력] 각 부문별 채용공고
#     직무: 백엔드/서버개발,웹개발,프론트엔드,Java,앱개발외수정일 25/08/06
#     근무지: 서울전체
#     경력: 신입·경력
#     학력: 학력무관
#     마감일: 채용시
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51121422&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [35]
#     제목: 도미노피자 각 부문(자회사 포함) 공개 채용
#     직무: 백엔드/서버개발,웹개발,프론트엔드,Java,앱개발외수정일 25/09/02
#     근무지: 서울전체
#     경력: 신입·경력
#     학력: 학력무관
#     마감일: ~ 10/03(금)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51710171&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [36]
#     제목: 각 부문별 채용
#     직무: 백엔드/서버개발,웹개발,프론트엔드,유지보수,웹마스터외수정일 25/08/28
#     근무지: 서울전체
#     경력: 신입·경력
#     학력: 학력무관
#     마감일: ~ 09/30(화)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51184056&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [37]
#     제목: (주)마인드차트 백엔드 개발자 모집
#     직무: 백엔드/서버개발,웹개발,MySQL,클라우드,Node.js외등록일 25/09/03
#     근무지: 서울송파구
#     경력: 경력무관
#     학력: 학력무관
#     마감일: ~ 10/03(금)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51731663&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [38]
#     제목: 타라소프트(주) NestJS 백엔드 개발자 채용 (신입/경력)
#     직무: 백엔드/서버개발,웹개발,Javascript,유지보수,MySQL외등록일 25/09/03
#     근무지: 서울금천구
#     경력: 경력무관
#     학력: 학력무관
#     마감일: ~ 09/16(화)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51730630&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [39]
#     제목: [집중채용] 빅데이터, C개발자, Elasticsearch Engineer
#     직무: 백엔드/서버개발,데이터분석가,데이터엔지니어,SE(시스템엔지니어),빅데이터외등록일 25/09/03
#     근무지: 서울강서구
#     경력: 신입·경력
#     학력: 학력무관
#     마감일: ~ 09/30(화)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51729161&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------
# [40]
#     제목: [코스닥 상장]보안제품 서비스 개발 (C/Go/Linux)
#     직무: 백엔드/서버개발,웹개발,SE(시스템엔지니어),네트워크,방화벽외등록일 25/09/03
#     근무지: 서울구로구
#     경력: 경력무관
#     학력: 학력무관
#     마감일: ~ 10/03(금)
#     지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51728255&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb
# ----------------------------------------------------------------------------------------------------

# %%
print(job_data) # list: [dict, dict, ...]
# Out:
# [{'회사명': '', '채용제목': '[시드소프트]SI개발&웹개발&백엔드/서버개발 외 정규직 채용', '직무분야': '백엔드/서버개발,웹개발,SI개발,소프트웨어개발수정일 25/08/31', '근무지': '서울구로구', '경력': '신입', '학력': '학력무관', '마감일': '~ 09/08(월)', '지원링크': 'https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51266037&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb'}, {'회사명': '', '채용제목': '영어회화 가능자', '직무분야': '백엔드/서버개발,기술지원,데이터엔지니어,IT컨설팅,SE(시스템엔지니어)외수정일 25/08/29', '근무지': '서울양천구', '경력': '신입', '학력': '학력무관', '마감일': '내일마감', '지원링크': 'https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51688737&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb'}, {'회사명': '', '채용제목': '2025년도 신입직원 채용공고', '직무분야': '백엔드/서버개발,프론트엔드,데이터분석가,데이터엔지니어,정보보안외수정일 25/09/03', '근무지': '서울전체', '경력': '신입', '학력': '학력무관', '마감일': '~ 09/12(금)', '지원링크': 'https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51720555&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb'}, {'회사명': '', '채용제목': '백엔드개발자(Node.js) [신입]', '직무분야': '백엔드/서버개발,MySQL,ElasticStack,Node.js,PostgreSQL외수정일 25/09/03', '근무지': '서울전체', '경력': '신입', '학력': '학력무관', '마감일': '~ 10/02(목)', '지원링크': 'https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51722568&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb'}, {'회사명': '', '채용제목': '백엔드개발 산업기능요원', '직무분야': '백엔드/서버개발,MySQL,ElasticStack,Node.js,PostgreSQL외수정일 25/09/03', '근무지': '서울전체', '경력': '신입', '학력': '학력무관', '마감일': '~ 10/02(목)', '지원링크': 'https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51722528&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb'}, {'회사명': '', '채용제목': '[신입] 플렉스지 유지보수 개발 및 운영 모집', '직무분야': '백엔드/서버개발,웹개발,Java,.NET,Ajax외수정일 25/09/03', '근무지': '서울금천구', '경력': '신입', '학력': '학력무관', '마감일': '채용시', '지원링크': 'https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51383887&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb'}, {'회사명': '', '채용제목': '[신입] JAVA 웹 개발자 채용', '직무분야': '백엔드/서버개발,웹개발,프론트엔드,유지보수,정보보안외수정일 25/08/29', '근무지': '서울금천구', '경력': '신입', '학력': '학력무관', '마감일': '~ 09/30(화)', '지원링크': 'https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51690978&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb'}, {'회사명': '', '채용제목': 'IT B2B 기술영업 및 세일즈', '직무분야': '백엔드/서버개발,웹개발,앱개발,QA/테스터,RTOS외수정일 25/08/27', '근무지': '서울영등포구', '경력': '신입', '학력': '고졸↑', '마감일': '~ 09/25(목)', '지원링크': 'https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51487131&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb'}, {'회사명': '', '채용제목': '[신입] 모바일 RTS 클라이언트 & 서버/MMORPG 클라이언트', '직무분야': '백엔드/서버개발,웹개발,Java,앱개발,Javascript외수정일 25/08/28', '근무지': '서울서초구', '경력': '신입', '학력': '학력무관', '마감일': '~ 10/25(토)', '지원링크': 'https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51656784&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb'}, {'회사명': '', '채용제목': '백업 / 보안 / 스토리지/ snfs 서버 정규직 채용합니다', '직무분야': '백엔드/서버개발,프론트엔드,유지보수,정보보안,SE(시스템엔지니어)외등록일 25/08/28', '근무지': '서울송파구', '경력': '신입', '학력': '학력무관', '마감일': '~ 09/27(토)', '지원링크': 'https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51675516&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb'}, {'회사명': '', '채용제목': '[캐시워크] 데이터엔지니어 인턴', '직무분야': '백엔드/서버개발,웹개발,Java,앱개발,Python외등록일 25/08/13', '근무지': '서울강남구', '경력': '신입', '학력': '학력무관', '마감일': '~ 10/12(일)', '지원링크': 'https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51551591&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb'}, {'회사명': '', '채용제목': '[신입] Backend(Java) 개발자 채용 공고', '직무분야': '백엔드/서버개발,웹개발,프론트엔드,Java,Javascript외등록일 25/08/14', '근무지': '서울구로구', '경력': '신입', '학력':  ...

# %%
# 사용자 질문
user_query = "취업 공고 정보를 분석하고, 취업 공고 정보를 요약해줘."

# 임베딩 리트리버
doc_score_pairs = similarity_docs_retrieval(user_query, job_data)
print('doc_score_pairs: ', doc_score_pairs)
# Out:
# ---------- 유사도 검색 시작 ----------
# device:  cuda
# 모델 로드 시작
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# 모델 로드 완료
# documents를 문자열로 변환 시작
# documents를 문자열로 변환 완료
# 임베딩 계산 시작
# 임베딩 계산 완료
# 코사인 유사도 점수 계산 시작
# 코사인 유사도 점수 계산 완료
# 문서와 유사도 점수 쌍 생성 및 정렬 시작
# 문서와 유사도 점수 쌍 생성 및 정렬 완료
# 문서와 유사도 점수 쌍 출력 시작
# 0.3518: 채용제목: 2025년도 신입직원 채용공고 | 직무분야: 백엔드/서버개발,프론트엔드,데이터분석가,데이터엔지니어,정보보안외수정일 25/09/03 | 근무지: 서울전체 | 경력: 신입 ...
# 0.3439: 채용제목: [집중채용] 빅데이터, C개발자, Elasticsearch Engineer | 직무분야: 백엔드/서버개발,데이터분석가,데이터엔지니어,SE(시스템엔지니어),빅데이터외등록일...
# 0.3436: 채용제목: [게임/IT] 취업 연계 연수생 모집 | 직무분야: 백엔드/서버개발,웹개발,Java,앱개발,유지보수외수정일 25/08/08 | 근무지: 서울전체 | 경력: 경력무관 | ...
# 0.3418: 채용제목: [81%취업] 빅데이터,AI 무료취업과정 모집! | 직무분야: 백엔드/서버개발,웹개발,Java,앱개발,Python외수정일 25/08/12 | 근무지: 광주남구 | 경력:...
# 0.3369: 채용제목: 2025년 하반기 신입 및 경력 대규모 채용 | 직무분야: 백엔드/서버개발,프론트엔드,사무보조,경영지원,광고영업외수정일 25/09/01 | 근무지: 서울전체 | 경력: ...
# 0.3316: 채용제목: 2025년 해커스 교육그룹 [신입/경력] 각 부문별 채용공고 | 직무분야: 백엔드/서버개발,웹개발,프론트엔드,Java,앱개발외수정일 25/08/06 | 근무지: 서울전체...
# 0.3270: 채용제목: 신입 및 경력직원 채용공고 | 직무분야: 백엔드/서버개발,유지보수,MySQL,기술지원,웹마스터외수정일 25/08/29 | 근무지: 서울전체 | 경력: 신입·경력 | 학력...
# 0.3099: 채용제목: 각 부문별 채용 | 직무분야: 백엔드/서버개발,웹개발,프론트엔드,유지보수,웹마스터외수정일 25/08/28 | 근무지: 서울전체 | 경력: 신입·경력 | 학력: 학력무관 ...
# 0.3060: 채용제목: [국비무료IT취업]자바파이썬/웹개발/빅데이터/인공지능 | 직무분야: 백엔드/서버개발,웹개발,프론트엔드,Java,앱개발외수정일 25/09/04 | 근무지: 서울마포구 | ...
# 0.3014: 채용제목: [국비교육생 모집]자바·빅데이터 취업훈련 | 직무분야: 백엔드/서버개발,프론트엔드,Java,Javascript,Python외수정일 25/09/04 | 근무지: 서울전체 ...
# 0.2985: 채용제목: [시드소프트]SI개발&웹개발&백엔드/서버개발 외 정규직 채용 | 직무분야: 백엔드/서버개발,웹개발,SI개발,소프트웨어개발수정일 25/08/31 | 근무지: 서울구로구 |...
# 0.2937: 채용제목: 영어회화 가능자 | 직무분야: 백엔드/서버개발,기술지원,데이터엔지니어,IT컨설팅,SE(시스템엔지니어)외수정일 25/08/29 | 근무지: 서울양천구 | 경력: 신입 | ...
# 0.2935: 채용제목: 도미노피자 각 부문(자회사 포함) 공개 채용 | 직무분야: 백엔드/서버개발,웹개발,프론트엔드,Java,앱개발외수정일 25/09/02 | 근무지: 서울전체 | 경력: 신입...
# 0.2935: 채용제목: ㈜우진플라임 부문별 인재채용 | 직무분야: 백엔드/서버개발,웹개발,앱개발,유지보수,SI개발외수정일 25/09/01 | 근무지: 서울전체 | 경력: 신입·경력 | 학력: ...
# 0.2861: 채용제목: ㈜위즈코리아 '25년 하반기 신입/경력 사원 모집 | 직무분야: 백엔드/서버개발,웹개발,프론트엔드,Java,Javascript외수정일 25/08/29 | 근무지: 서울전...
# 0.2842: 채용제목: IT B2B 기술영업 및 세일즈 | 직무분야: 백엔드/서버개발,웹개발,앱개발,QA/테스터,RTOS외수정일 25/08/27 | 근무지: 서울영등포구 | 경력: 신입 | 학...
# 0.2836: 채용제목: [신입] Backend(Java) 개발자 채용 공고 | 직무분야: 백엔드/서버개발,웹개발,프론트엔드,Java,Javascript외등록일 25/08/14 | 근무지: 서울...
# 0.2834: 채용제목: 백업 / 보안 / 스토리지/ snfs 서버 정규직 채용합니다 | 직무분야: 백엔드/서버개발,프론트엔드,유지보수,정보보안,SE(시스템엔지니어)외등록일 25/08/28 | ...
# 0.2809: 채용제목: [신입] 플렉스지 유지보수 개발 및 운영 모집 | 직무분야: 백엔드/서버개발,웹개발,Java,.NET,Ajax외수정일 25/09/03 | 근무지: 서울금천구 | 경력: ...
# 0.2793: 채용제목: 백엔드개발 산업기능요원 | 직무분야: 백엔드/서버개발,MySQL,ElasticStack,Node.js,PostgreSQL외수정일 25/09/03 | 근무지: 서울전체 |...
# 0.2759: 채용제목: KT Cloud 테크센터 인력 모집 (스케줄 근무) | 직무분야: 백엔드/서버개발,SE(시스템엔지니어),Windows,Linux,시스템관리등록일 25/09/04 | 근무...
# 0.2739: 채용제목: 백엔드개발자(Node.js) [신입] | 직무분야: 백엔드/서버개발,MySQL,ElasticStack,Node.js,PostgreSQL외수정일 25/09/03 | 근무지...
# 0.2677: 채용제목: [광고대행사] 개발팀 채용공고 | 직무분야: 백엔드/서버개발,프론트엔드,유지보수,API,DevOps외수정일 25/07/28 | 근무지: 서울금천구 | 경력: 경력무관 |...
# 0.2666: 채용제목: AI 지능형 CCTV, 우수조달 제품 영업담당 | 직무분야: 백엔드/서버개발,기술영업,솔루션기술영업,IT영업,SI영업외수정일 25/09/04 | 근무지: 서울송파구 | ...
# 0.2630: 채용제목: 백엔드/서버개발자 모집 | 직무분야: 백엔드/서버개발,안드로이드,텔레매틱스,모바일APP,무선통신등록일 25/09/03 | 근무지: 서울구로구 | 경력: 경력무관 | 학력...
# 0.2629: 채용제목: [서비시개발] 서비스 기획 및 백엔드, 프론트엔드 개발 채용 | 직무분야: 백엔드/서버개발,앱개발,서비스기획,SI·시스템통합,소프트웨어개발등록일 25/09/04 | 근무...
# 0.2597: 채용제목: [코스닥 상장]보안제품 서비스 개발 (C/Go/Linux) | 직무분야: 백엔드/서버개발,웹개발,SE(시스템엔지니어),네트워크,방화벽외등록일 25/09/03 | 근무지:...
# 0.2528: 채용제목: ㈜위즈코리아 SE(시스템 엔지니어), PM 채용 | 직무분야: 백엔드/서버개발,웹개발,유지보수,정보보안,솔루션외수정일 25/08/29 | 근무지: 서울전체 | 경력: 신...
# 0.2517: 채용제목: [신입] JAVA 웹 개발자 채용 | 직무분야: 백엔드/서버개발,웹개발,프론트엔드,유지보수,정보보안외수정일 25/08/29 | 근무지: 서울금천구 | 경력: 신입 | 학...
# 0.2443: 채용제목: (주)미스릴 인공지능 연구개발 담당 연구원 모집 | 직무분야: 백엔드/서버개발,웹개발,프론트엔드,Python,IT컨설팅외수정일 25/09/04 | 근무지: 서울송파구 |...
# 0.2411: 채용제목: [신입] 모바일 RTS 클라이언트 & 서버/MMORPG 클라이언트 | 직무분야: 백엔드/서버개발,웹개발,Java,앱개발,Javascript외수정일 25/08/28 | 근...
# 0.2403: 채용제목: [캐시워크] 백엔드개발 채용전환형 인턴 | 직무분야: 백엔드/서버개발,웹개발,Java,앱개발,Python외등록일 25/08/06 | 근무지: 서울강남구 | 경력: 신입 ...
# 0.2398: 채용제목: Ai Agent Developer 채용 | 직무분야: 백엔드/서버개발,Javascript,Python,데이터분석가,데이터엔지니어외등록일 25/08/04 | 근무지: 서울...
# 0.2382: 채용제목: (주)마인드차트 백엔드 개발자 모집 | 직무분야: 백엔드/서버개발,웹개발,MySQL,클라우드,Node.js외등록일 25/09/03 | 근무지: 서울송파구 | 경력: 경력...
# 0.2325: 채용제목: 파이썬(Python) 기반의 풀스택 개발자 모십니다. | 직무분야: 백엔드/서버개발,프론트엔드,Javascript,Python,유지보수외등록일 25/09/04 | 근무지...
# 0.2257: 채용제목: [캐시워크] 데이터엔지니어 인턴 | 직무분야: 백엔드/서버개발,웹개발,Java,앱개발,Python외등록일 25/08/13 | 근무지: 서울강남구 | 경력: 신입 | 학력...
# 0.2163: 채용제목: PM 거래처영업/관리  아웃소싱관리 S/W 개발자 채용 | 직무분야: 백엔드/서버개발,웹개발,Python,SI개발,임베디드외수정일 25/08/19 | 근무지: 서울강서구...
# 0.2036: 채용제목: Product Engineer 인턴 (채용 연계형) | 직무분야: 백엔드/서버개발,웹개발,프론트엔드,앱개발,기술지원수정일 25/09/04 | 근무지: 서울서초구 | 경력...
# 0.2023: 채용제목: (주)세피스 그룹웨어 솔루션 개발(C#,Net MVC) 신입/경력 채용 | 직무분야: 백엔드/서버개발,웹개발,프론트엔드,.NET,C#외등록일 25/09/04 | 근무지:...
# 0.1884: 채용제목: 타라소프트(주) NestJS 백엔드 개발자 채용 (신입/경력) | 직무분야: 백엔드/서버개발,웹개발,Javascript,유지보수,MySQL외등록일 25/09/03 | 근...
# 문서와 유사도 점수 쌍 출력 완료
# doc_score_pairs:  [('채용제목: 2025년도 신입직원 채용공고 | 직무분야: 백엔드/서버개발,프론트엔드,데이터분석가,데이터엔지니어,정보보안외수정일 25/09/03 | 근무지: 서울전체 | 경력: 신입 | 학력: 학력무관 | 마감일: ~ 09/12(금) | 지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51720555&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb', tensor(0.3518)), ('채용제목: [집중채용] 빅데이터, C개발자, Elasticsearch Engineer | 직무분야: 백엔드/서버개발,데이터분석가,데이터엔지니어,SE(시스템엔지니어),빅데이터외등록일 25/09/03 | 근무지: 서울강서구 | 경력: 신입·경력 | 학력: 학력무관 | 마감일: ~ 09/30(화) | 지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51729161&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb', tensor(0.3439)), ('채용제목: [게임/IT] 취업 연계 연수생 모집 | 직무분야: 백엔드/서버개발,웹개발,Java,앱개발,유지보수외수정일 25/08/08 | 근무지: 서울전체 | 경력: 경력무관 | 학력: 학력무관 | 마감일: 오늘마감 | 지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51502151&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb', tensor(0.3436)), ('채용제목: [81%취업] 빅데이터,AI 무료취업과정 모집! | 직무분야: 백엔드/서버개발,웹개발,Java,앱개발,Python외수정일 25/08/12 | 근무지: 광주남구 | 경력: 경력무관 | 학력: 학력무관 | 마감일: ~ 04/08(수) | 지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51127978&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb', tensor(0.3418)), ('채용제목: 2025년 하반기 신입 및 경력 대규모 채용 | 직무분야: 백엔드/서버개발,프론트엔드,사무보조,경영지원,광고영업외수정일 25/09/01 | 근무지: 서울전체 | 경력: 신입·경력 | 학력: 학력무관 | 마감일: ~ 09/30(화) | 지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51161938&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb', tensor(0.3369)), ('채용제목: 2025년 해커스 교육그룹 [신입/경력] 각 부문별 채용공고 | 직무분야: 백엔드/서버개발,웹개발,프론트엔드,Java,앱개발외수정일 25/08/06 | 근무지: 서울전체 | 경력: 신입·경력 | 학력: 학력무관 | 마감일: 채용시 | 지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51121422&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb', tensor(0.3316)), ('채용제목: 신입 및 경력직원 채용공고 | 직무분야: 백엔드/서버개발,유지보수,MySQL,기술지원,웹마스터외수정일 25/08/29 | 근무지: 서울전체 | 경력: 신입·경력 | 학력: 학력무관 | 마감일: ~ 09/10(수) | 지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51146371&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb', tensor(0.3270)), ('채용제목: 각 부문별 채용 | 직무분야: 백엔드/서버개발,웹개발,프론트엔드,유지보수,웹마스터외수정일 25/08/28 | 근무지: 서울전체 | 경력: 신입·경력 | 학력: 학력무관 | 마감일: ~ 09/30(화) | 지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51184056&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb', tensor(0.3099)), ('채용제목: [국비무료IT취업]자바파이썬/웹개발/빅데이터/인공지능 | 직무분야: 백엔드/서버개발,웹개발,프론트엔드,Java,앱개발외수정일 25/09/04 | 근무지: 서울마포구 | 경력: 경력무관 | 학력: 학력무관 | 마감일: ~ 09/07(일) | 지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51502181&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb', tensor(0.3060)), ('채용제목: [국비교육생 모집]자바·빅데이터 취업훈련 | 직무분야: 백엔드/서버개발,프론트엔드,Java,Javascript,Python외수정일 25/09/04 | 근무지: 서울전체 | 경력: 경력무관 | 학력: 학력무관 | 마감일: ~ 09/16(화) | 지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51741651&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb', tensor(0.3014)), ('채용제목: [시드소프트]SI개발&웹개발&백엔드/서버개발 외 정규직 채용 | 직무분야: 백엔드/서버개발,웹개발,SI개발,소프트웨어개발수정일 25/08/31 | 근무지: 서울구로구 | 경력: 신입 | 학력: 학력무관 | 마감일: ~ 09/08(월) | 지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51266037&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4dea-8890-6ecff31d6edb', tensor(0.2985)), ('채용제목: 영어회화 가능자 | 직무분야: 백엔드/서버개발,기술지원,데이터엔지니어,IT컨설팅,SE(시스템엔지니어)외수정일 25/08/29 | 근무지: 서울양천구 | 경력: 신입 | 학력: 학력무관 | 마감일: 내일마감 | 지원링크: https://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=search&rec_idx=51688737&location=ts&searchType=search&paid_fl=n&search_uuid=645e0fd5-0932-4 ...

# %%
response = generate_response(user_query, job_data)
print(f"LLM 응답: {response}")
# Out:
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.60G [00:00<?, ?B/s]
